# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>Data Wrangling EDA with Pandas</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |

# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %matplotlib inline

import warnings

warnings.filterwarnings("ignore")

# %%
employee_df = pd.read_csv('Human_Resources.csv')
employee_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
employee_df.tail()
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [5 rows x 35 columns]

# %%
employee_df.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
summary = employee_df.describe()
summary
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# std              0.0      601.646166                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      492.000000                 2.000000    48.000000
# 50%              1.0     1022.000000                 3.000000    66.000000
# 75%              1.0     1556.000000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
num_features = len(employee_df.columns)
num_features
# Out:
# 35

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
mean_age = employee_df['Age'].mean()
max_age = employee_df['Age'].max()
min_age = employee_df['Age'].min()

# %%
mean_age
# Out:
# 36.923809523809524

# %%
max_age
# Out:
# 60

# %%
min_age
# Out:
# 18

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
null_rows = employee_df[employee_df.isnull().any(axis=1)]
null_rows
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 6     59            NaN        No      Travel_Rarely       1324
# 7     30         2693.0        No      Travel_Rarely       1358
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 6    Research & Development                 3          3            NaN
# 7                       NaN                24          1  Life Sciences
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# 103  Research & Development                 6          4          Other
# 947                   Sales                 5          3  Life Sciences
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1                1  ...                         4             80
# 6                1  ...                         1             80
# 7                1  ...                         2             80
# 17               1  ...                         2             80
# 23               1  ...                         4             80
# 103              1  ...                         3             80
# 947              1  ...                         3             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1                  1                 10                      3
# 6                  3                 12                      3
# 7                  1                  1                      2
# 17                 2                  1                      2
# 23                 0                  0                      6
# 103                0                 16                      3
# 947                0                 10                      2
#
#      WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 1                  3             10                   7
# 6                  2              1                   0
# 7                  3              1                   0
# 17                 2              1                   0
# 23                 3              0                   0
# 103                3             16                  13
# 947                2              8                   7
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 1                         1                     7
# 6                         0                     0
# 7                         0                     0
# 17                        0                     0
# 23                        0                     0
# 103                       2                    10
# 947                       7                     7
#
# [7 rows x 35 columns]

# %%
missing_per_column = employee_df.isnull().sum()
missing_per_column
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
employee_df = employee_df.dropna()
employee_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# 5                 1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# 5                   0                  8                      2
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# 5                   2              7                   7
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# 5                          3                     6
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1463 rows x 35 columns]

# %%
employee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1463 non-null   int64
#  1   MonthlyIncome             1463 non-null   float64
#  2   Attrition                 1463 non-null   object
#  3   BusinessTravel            1463 non-null   object
#  4   DailyRate                 1463 non-null   int64
#  5   Department                1463 non-null   object
#  6   DistanceFromHome          1463 non-null   int64
#  7   Education                 1463 non-null   int64
#  8   EducationField            1463 non-null   object
#  9   EmployeeCount             1463 non-null   int64
#  10  EmployeeNumber            1463 non-null   float64
#  11  EnvironmentSatisfaction   1463 non-null   int64
#  12  Gender                    1463 non-null   object
#  13  HourlyRate                1463 non-null   int64
#  14  JobInvolvement            1463 non-null   int64
#  15  JobLevel                  1463 non-null   int64
#  16  JobRole                   1463 non-null   object
#  17  JobSatisfaction           1463 non-null   int64
#  18  MaritalStatus             1463 non-null   object
#  19  MonthlyRate               1463 non-null   float64
#  20  NumCompaniesWorked        1463 non-null   int64
#  21  Over18                    1463 non-null   object
#  22  OverTime                  1463 non-null   object
#  23  PercentSalaryHike         1463 non-null   float64
#  24  PerformanceRating         1463 non-null   float64
#  25  RelationshipSatisfaction  1463 non-null   int64
#  26  StandardHours             1463 non-null   int64
#  27  StockOptionLevel          1463 non-null   int64
#  28  TotalWorkingYears         1463 non-null   int64
#  29  TrainingTimesLastYear     1463 non-null   int64
#  30  WorkLifeBalance           1463 non-null   int64
#  31  YearsAtCompany            1463 non-null   int64
#  32  YearsInCurrentRole        1463 non-null   int64
#  33  YearsSinceLastPromotion   1463 non-null   int64
#  34  YearsWithCurrManager      1463 non-null   int64
# dtypes: float64(5), int64(21), object(9)
# memory usage: 411.5+ KB

# %%
any_missing_values = employee_df.isnull().any().any()
any_missing_values
# Out:
# False

# %%
avg_monthly_income = employee_df['MonthlyIncome'].mean()
avg_monthly_income
# Out:
# 6514.965140123035

# %%
employee_df['MonthlyIncome'] = employee_df['MonthlyIncome'].fillna(0)
employee_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# 5                 1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# 5                   0                  8                      2
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# 5                   2              7                   7
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# 5                          3                     6
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1463 rows x 35 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
median_monthly_rate = employee_df['MonthlyRate'].median()
median_monthly_rate
# Out:
# 14242.0

# %%
employee_df['MonthlyRate'].fillna(median_monthly_rate, inplace=True)
employee_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# 5                 1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# 5                   0                  8                      2
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# 5                   2              7                   7
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# 5                          3                     6
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1463 rows x 35 columns]

# %%
any_missing_values = employee_df.isnull().any().any()
any_missing_values
# Out:
# False

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING [OPTIONAL]

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1470 rows x 35 columns]

# %%
hr_df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
hr_df['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 1       Travel_Frequently
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
BusinessTravel_Encoded = pd.get_dummies(hr_df['BusinessTravel'])
print(BusinessTravel_Encoded)
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0          False              False           True
# 1          False               True          False
# 2          False              False           True
# 3          False               True          False
# 4          False              False           True
# ...          ...                ...            ...
# 1465       False               True          False
# 1466       False              False           True
# 1467       False              False           True
# 1468       False               True          False
# 1469       False              False           True
#
# [1470 rows x 3 columns]

# %%
hr_df.dropna(inplace=True)
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 4                 1  ...                         4             80
# 5                 1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 2                   0                  7                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# 5                   0                  8                      2
# ...               ...                ...                    ...
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1467                1                  6                      0
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 2                   3              0                   0
# 3                   3              8                   7
# 4                   3              2                   2
# 5                   2              7                   7
# ...               ...            ...                 ...
# 1465                3              5                   2
# 1466                3              7                   7
# 1467                3              6                   2
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 2                          0                     0
# 3                          3                     0
# 4                          2                     2
# 5                          3                     6
# ...                      ...                   ...
# 1465                       0                     3
# 1466                       1                     7
# 1467                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [1463 rows x 35 columns]

# %%
employee_df['EducationField'].nunique()
# Out:
# 6

# %%
hr_df_encoded = pd.get_dummies(hr_df, columns=['EducationField'], prefix='EducationField')

# %%
hr_df_encoded
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education  EmployeeCount  \
# 0                      Sales                 1          2              1
# 2     Research & Development                 2          2              1
# 3     Research & Development                 3          4              1
# 4     Research & Development                 2          1              1
# 5     Research & Development                 2          2              1
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2              1
# 1466  Research & Development                 6          1              1
# 1467  Research & Development                 4          3              1
# 1468                   Sales                 2          3              1
# 1469  Research & Development                 8          3              1
#
#       EmployeeNumber  ...  YearsAtCompany YearsInCurrentRole  \
# 0                1.0  ...               6                  4
# 2                4.0  ...               0                  0
# 3                5.0  ...               8                  7
# 4                7.0  ...               2                  2
# 5                8.0  ...               7                  7
# ...              ...  ...             ...                ...
# 1465          2061.0  ...               5                  2
# 1466          2062.0  ...               7                  7
# 1467          2064.0  ...               6                  2
# 1468          2065.0  ...               9                  6
# 1469          2068.0  ...               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                           0                     5
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# 5                           3                     6
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
#       EducationField_Human Resources EducationField_Life Sciences  \
# 0                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
# 5                              False                         True
# ...                              ...                          ...
# 1465                           False                        False
# 1466                           False                        False
# 1467                           False                         True
# 1468                           False                        False
# 1469                           False                        False
#
#       EducationField_Marketing EducationField_Medical  EducationField_Other  \
# 0                        False                  False                 False
# 2                        False                  False                  True
# 3                        False                  False                 False
# 4                        False                   True                 False
# 5                        False                  False                 False
# ...                        ...                    ...                   ...
# 1465                     False                   True                 False
# 1466                     False                   True                 False
# 1467                     False                  False                 False
# 1468                     False                   True                 False
# 1469                     False                   True                 False
#
#       EducationField_Technical Degree
# 0                               False
# 2                               False
# 3                               False
# 4                               False
# 5                               False
# ...                               ...
# 1465                            False
# 1466                            False
# 1467                            False
# 1468                            False
# 1469                            False
#
# [1463 rows x 40 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
hr_df['Age'].values
# Out:
# array([41, 49, 37, ..., 27, 49, 34], dtype=int64)

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df['Age']
# Out:
# 0       0.547619
# 1       0.738095
# 2       0.452381
# 3       0.357143
# 4       0.214286
#           ...
# 1465    0.428571
# 1466    0.500000
# 1467    0.214286
# 1468    0.738095
# 1469    0.380952
# Name: Age, Length: 1470, dtype: float64

# %%
hr_df.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean      0.450567    6505.155419   802.485714          9.192517     2.912925
# std       0.217509    4711.297846   403.509100          8.106864     1.024165
# min       0.000000    1009.000000   102.000000          1.000000     1.000000
# 25%       0.285714    2911.000000   465.000000          2.000000     2.000000
# 50%       0.428571    4908.000000   802.000000          7.000000     3.000000
# 75%       0.595238    8378.000000  1157.000000         14.000000     4.000000
# max       1.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# std              0.0      601.646166                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      492.000000                 2.000000    48.000000
# 50%              1.0     1022.000000                 3.000000    66.000000
# 75%              1.0     1556.000000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
selected_rows = hr_df[hr_df['Age'] > 30]

# %%
selected_rows
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1463   31         9936.0        No         Non-Travel        325
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# 2     Research & Development                 2          2          Other
# 3     Research & Development                 3          4  Life Sciences
# 5     Research & Development                 2          2  Life Sciences
# ...                      ...               ...        ...            ...
# 1463  Research & Development                 5          3        Medical
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 1                 1  ...                         4             80
# 2                 1  ...                         2             80
# 3                 1  ...                         3             80
# 5                 1  ...                         3             80
# ...             ...  ...                       ...            ...
# 1463              1  ...                         2             80
# 1465              1  ...                         3             80
# 1466              1  ...                         1             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 1                   1                 10                      3
# 2                   0                  7                      3
# 3                   0                  8                      3
# 5                   0                  8                      2
# ...               ...                ...                    ...
# 1463                0                 10                      2
# 1465                1                 17                      3
# 1466                1                  9                      5
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 1                   3             10                   7
# 2                   3              0                   0
# 3                   3              8                   7
# 5                   2              7                   7
# ...               ...            ...                 ...
# 1463                3              9                   4
# 1465                3              5                   2
# 1466                3              7                   7
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 1                          1                     7
# 2                          0                     0
# 3                          3                     0
# 5                          3                     6
# ...                      ...                   ...
# 1463                       1                     7
# 1465                       0                     3
# 1466                       1                     7
# 1468                       0                     8
# 1469                       1                     2
#
# [1084 rows x 35 columns]

# %%
selected_rows = hr_df[(hr_df['Age'] > 30) & (hr_df['Department'] == 'Sales')]
selected_rows
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate Department  \
# 0      41         5993.0       Yes      Travel_Rarely       1102      Sales
# 18     53        15427.0        No      Travel_Rarely       1219      Sales
# 21     36         3407.0       Yes      Travel_Rarely       1218      Sales
# 27     42         6825.0        No      Travel_Rarely        691      Sales
# 29     46        18947.0        No      Travel_Rarely        705      Sales
# ...   ...            ...       ...                ...        ...        ...
# 1453   36         6652.0        No      Travel_Rarely       1120      Sales
# 1454   45         4850.0        No      Travel_Rarely        374      Sales
# 1461   50        10854.0       Yes      Travel_Rarely        410      Sales
# 1462   39        12031.0        No      Travel_Rarely        722      Sales
# 1468   49         5390.0        No  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                    1          2  Life Sciences              1  ...
# 18                   2          4  Life Sciences              1  ...
# 21                   9          4  Life Sciences              1  ...
# 27                   8          4      Marketing              1  ...
# 29                   2          4      Marketing              1  ...
# ...                ...        ...            ...            ...  ...
# 1453                11          4      Marketing              1  ...
# 1454                20          3  Life Sciences              1  ...
# 1461                28          3      Marketing              1  ...
# 1462                24          1      Marketing              1  ...
# 1468                 2          3        Medical              1  ...
#
#       RelationshipSatisfaction  StandardHours StockOptionLevel  \
# 0                            1             80                0
# 18                           3             80                0
# 21                           2             80                0
# 27                           4             80                1
# 29                           4             80                0
# ...                        ...            ...              ...
# 1453                         1             80                1
# 1454                         3             80                0
# 1461                         2             80                1
# 1462                         1             80                1
# 1468                         4             80                0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 18                   31                      3                3
# 21                   10                      4                3
# 27                   10                      2                3
# 29                   22                      2                2
# ...                 ...                    ...              ...
# 1453                  8                      2                2
# 1454                  8                      3                3
# 1461                 20                      3                3
# 1462                 21                      2                2
# 1468                 17                      3                2
#
#      YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0                 6                   4                       0
# 18               25                   8                       3
# 21                5                   3                       0
# 27                9                   7                       4
# 29                2                   2                       2
# ...             ...                 ...                     ...
# 1453              6                   3                       0
# 1454              5                   3                       0
# 1461              3                   2                       2
# 1462             20                   9                       9
# 1468              9                   6                       0
#
#       YearsWithCurrManager
# 0                        5
# 18                       7
# 21                       3
# 27                       2
# 29                       1
# ...                    ...
# 1453                     0
# 1454                     1
# 1461                     0
# 1462                     6
# 1468                     8
#
# [330 rows x 35 columns]

# %%
selected_rows = hr_df[hr_df['MonthlyIncome'].between(4000, 6000)]

# %%
selected_rows
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 9      36         5237.0        No      Travel_Rarely       1299
# 11     29         4193.0        No      Travel_Rarely        153
# 20     24         4011.0        No         Non-Travel        673
# 39     33         5376.0        No  Travel_Frequently       1141
# ...   ...            ...       ...                ...        ...
# 1454   45         4850.0        No      Travel_Rarely        374
# 1456   35         5689.0        No  Travel_Frequently       1199
# 1459   29         4025.0        No      Travel_Rarely       1378
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 9     Research & Development                27          3        Medical
# 11    Research & Development                15          2  Life Sciences
# 20    Research & Development                11          2          Other
# 39                     Sales                 1          3  Life Sciences
# ...                      ...               ...        ...            ...
# 1454                   Sales                20          3  Life Sciences
# 1456  Research & Development                18          4  Life Sciences
# 1459  Research & Development                13          2          Other
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0                 1  ...                         1             80
# 9                 1  ...                         2             80
# 11                1  ...                         4             80
# 20                1  ...                         4             80
# 39                1  ...                         1             80
# ...             ...  ...                       ...            ...
# 1454              1  ...                         3             80
# 1456              1  ...                         4             80
# 1459              1  ...                         1             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                   0                  8                      0
# 9                   2                 17                      3
# 11                  0                 10                      3
# 20                  1                  5                      5
# 39                  2                 10                      3
# ...               ...                ...                    ...
# 1454                0                  8                      3
# 1456                2                 10                      2
# 1459                1                 10                      2
# 1468                0                 17                      3
# 1469                0                  6                      3
#
#       WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 0                   1              6                   4
# 9                   2              7                   7
# 11                  3              9                   5
# 20                  2              4                   2
# 39                  3              5                   3
# ...               ...            ...                 ...
# 1454                3              5                   3
# 1456                4             10                   2
# 1459                3              4                   3
# 1468                2              9                   6
# 1469                4              4                   3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 0                          0                     5
# 9                          7                     7
# 11                         0                     8
# 20                         1                     3
# 39                         1                     3
# ...                      ...                   ...
# 1454                       0                     1
# 1456                       0                     2
# 1459                       0                     3
# 1468                       0                     8
# 1469                       1                     2
#
# [371 rows x 35 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
high_daily_rate_df = hr_df[hr_df['DailyRate'] >= 1450]

# %%
high_daily_rate_df.head(10)
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 31    44         6465.0        No      Travel_Rarely       1459
# 52    44         5454.0        No      Travel_Rarely       1488
# 110   51         7484.0        No  Travel_Frequently       1456
# 117   36         9738.0        No  Travel_Frequently       1467
# 155   29         4319.0        No         Non-Travel       1496
# 164   27         2566.0        No         Non-Travel       1450
# 165   50        19926.0        No      Travel_Rarely       1452
# 172   36         2088.0        No  Travel_Frequently       1480
# 213   51        12490.0        No      Travel_Rarely       1469
# 266   31         5582.0        No      Travel_Rarely       1463
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 31   Research & Development                10          4             Other
# 52                    Sales                 1          5         Marketing
# 110  Research & Development                 1          4           Medical
# 117                   Sales                11          2  Technical Degree
# 155  Research & Development                 1          1  Technical Degree
# 164  Research & Development                 3          3           Medical
# 165  Research & Development                11          3     Life Sciences
# 172  Research & Development                 3          2           Medical
# 213  Research & Development                 8          4     Life Sciences
# 266  Research & Development                23          3           Medical
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 31               1  ...                         4             80
# 52               1  ...                         3             80
# 110              1  ...                         3             80
# 117              1  ...                         3             80
# 155              1  ...                         1             80
# 164              1  ...                         4             80
# 165              1  ...                         2             80
# 172              1  ...                         3             80
# 213              1  ...                         4             80
# 266              1  ...                         2             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 31                 0                  9                      5
# 52                 1                  9                      2
# 110                0                 23                      1
# 117                1                 10                      6
# 155                1                 10                      1
# 164                1                  1                      2
# 165                0                 21                      5
# 172                0                 13                      3
# 213                2                 16                      5
# 266                1                 10                      2
#
#      WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# 31                 4              4                   2
# 52                 2              4                   3
# 110                2             13                  12
# 117                3              9                   7
# 155                3             10                   7
# 164                2              1                   1
# 165                3              5                   4
# 172                2              8                   7
# 213                1             10                   9
# 266                3              9                   0
#
#     YearsSinceLastPromotion  YearsWithCurrManager
# 31                        1                     3
# 52                        1                     3
# 110                      12                     8
# 117                       2                     8
# 155                       0                     9
# 164                       0                     1
# 165                       4                     4
# 172                       7                     2
# 213                       4                     7
# 266                       7                     8
#
# [10 rows x 35 columns]

# %%
combined_daily_rate = high_daily_rate_df['DailyRate'].sum()

# %%
combined_daily_rate
# Out:
# 73749

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
columns_to_drop = ['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber']
hr_df = hr_df.drop(columns=columns_to_drop)

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...               3.0                         1
# 1                        3  ...               4.0                         4
# 2                        4  ...               3.0                         2
# 3                        4  ...               3.0                         3
# 4                        1  ...               3.0                         4
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 0                  8                     0                1
# 1                 1                 10                     3                3
# 2                 0                  7                     3                3
# 3                 0                  8                     3                3
# 4                 1                  6                     3                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0              6                   4                        0
# 1             10                   7                        1
# 2              0                   0                        0
# 3              8                   7                        3
# 4              2                   2                        2
#
#   YearsWithCurrManager
# 0                    5
# 1                    7
# 2                    0
# 3                    0
# 4                    2
#
# [5 rows x 31 columns]

# %%
num_employees_left = hr_df['Attrition'].value_counts()['Yes']
employees_who_left = hr_df[hr_df['Attrition'] == 'Yes']

# %%
num_employees_left
# Out:
# 237

# %%
employees_who_left
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 14     28         2028.0       Yes      Travel_Rarely        103
# 21     36         3407.0       Yes      Travel_Rarely       1218
# 24     34         2960.0       Yes      Travel_Rarely        699
# ...   ...            ...       ...                ...        ...
# 1438   23         1790.0       Yes  Travel_Frequently        638
# 1442   29         4787.0       Yes      Travel_Rarely       1092
# 1444   56         2339.0       Yes      Travel_Rarely        310
# 1452   50         6728.0       Yes  Travel_Frequently        878
# 1461   50        10854.0       Yes      Travel_Rarely        410
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 0                      Sales                 1          2     Life Sciences
# 2     Research & Development                 2          2             Other
# 14    Research & Development                24          3     Life Sciences
# 21                     Sales                 9          4     Life Sciences
# 24    Research & Development                 6          1           Medical
# ...                      ...               ...        ...               ...
# 1438                   Sales                 9          3         Marketing
# 1442  Research & Development                 1          4           Medical
# 1444  Research & Development                 7          2  Technical Degree
# 1452                   Sales                 1          4     Life Sciences
# 1461                   Sales                28          3         Marketing
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 0                           2  ...               3.0
# 2                           4  ...               3.0
# 14                          3  ...               3.0
# 21                          3  ...               4.0
# 24                          2  ...               3.0
# ...                       ...  ...               ...
# 1438                        4  ...               3.0
# 1442                        1  ...               3.0
# 1444                        4  ...               3.0
# 1452                        2  ...               3.0
# 1461                        4  ...               3.0
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                            1                 0                  8
# 2                            2                 0                  7
# 14                           2                 0                  6
# 21                           2                 0                 10
# 24                           3                 0                  8
# ...                        ...               ...                ...
# 1438                         1                 1                  1
# 1442                         2                 3                  4
# 1444                         4                 1                 14
# 1452                         4                 2                 12
# 1461                         2                 1                 20
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                        0                1              6
# 2                        3                3              0
# 14                       4                3              4
# 21                       4                3              5
# 24                       2                3              4
# ...                    ...              ...            ...
# 1438                     3                2              1
# 1442                     3                4              2
# 1444                     4                1             10
# 1452                     3                3              6
# 1461                     3                3              3
#
#       YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                      4                        0                    5
# 2                      0                        0                    0
# 14                     2                        0                    3
# 21                     3                        0                    3
# 24                     2                        1                    3
# ...                  ...                      ...                  ...
# 1438                   0                        1                    0
# 1442                   2                        2                    2
# 1444                   9                        9                    8
# 1452                   3                        0                    1
# 1461                   2                        2                    0
#
# [237 rows x 31 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
num_employees_stay = hr_df['Attrition'].value_counts()['No']

# %%
num_employees_stay
# Out:
# 1233

# %%
employees_who_stay = hr_df[hr_df['Attrition'] == 'No']

# %%
employees_who_stay
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1      49            NaN        No  Travel_Frequently        279
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# 6      59            NaN        No      Travel_Rarely       1324
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1     Research & Development                 8          1  Life Sciences
# 3     Research & Development                 3          4  Life Sciences
# 4     Research & Development                 2          1        Medical
# 5     Research & Development                 2          2  Life Sciences
# 6     Research & Development                 3          3            NaN
# ...                      ...               ...        ...            ...
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EnvironmentSatisfaction  ... PerformanceRating  \
# 1                           3  ...               4.0
# 3                           4  ...               3.0
# 4                           1  ...               3.0
# 5                           4  ...               3.0
# 6                           3  ...               NaN
# ...                       ...  ...               ...
# 1465                        3  ...               3.0
# 1466                        4  ...               3.0
# 1467                        2  ...               4.0
# 1468                        4  ...               3.0
# 1469                        2  ...               3.0
#
#       RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 1                            4                 1                 10
# 3                            3                 0                  8
# 4                            4                 1                  6
# 5                            3                 0                  8
# 6                            1                 3                 12
# ...                        ...               ...                ...
# 1465                         3                 1                 17
# 1466                         1                 1                  9
# 1467                         2                 1                  6
# 1468                         4                 0                 17
# 1469                         1                 0                  6
#
#      TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 1                        3                3             10
# 3                        3                3              8
# 4                        3                3              2
# 5                        2                2              7
# 6                        3                2              1
# ...                    ...              ...            ...
# 1465                     3                3              5
# 1466                     5                3              7
# 1467                     0                3              6
# 1468                     3                2              9
# 1469                     3                4              4
#
#       YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 1                      7                        1                    7
# 3                      7                        3                    0
# 4                      2                        2                    2
# 5                      7                        3                    6
# 6                      0                        0                    0
# ...                  ...                      ...                  ...
# 1465                   2                        0                    3
# 1466                   7                        1                    7
# 1467                   2                        0                    3
# 1468                   6                        0                    8
# 1469                   3                        1                    2
#
# [1233 rows x 31 columns]

# %%
employees_who_stay.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# std                   1.071132    20.380754        0.692050     1.117933
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    48.000000        2.000000     1.000000
# 50%                   3.000000    66.000000        3.000000     2.000000
# 75%                   4.000000    83.000000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  ...  PerformanceRating  RelationshipSatisfaction  \
# count      1233.000000  ...        1232.000000               1233.000000
# mean          2.778589  ...           3.152597                  2.733982
# std           1.093277  ...           0.359745                  1.071603
# min           1.000000  ...           3.000000                  1.000000
# 25%           2.000000  ...           3.000000                  2.000000
# 50%           3.000000  ...           3.000000                  3.000000
# 75%           4.000000  ...           3.000000                  4.000000
# max           4.000000  ...           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1233.000000        1233.000000            1233.000000
# mean           0.845093          11.862936               2.832928
# std            0.841985           7.760719               1.293585
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          16.000000               3.000000
# max            3.000000          38.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1233.000000     1233.000000         1233.000000
# mean          2.781022        7.369019            4.484185
# std           0.681907        6.096298            3.649402
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        6.000000            3.000000
# 75%           3.000000       10.000000            7.000000
# max           4.000000       37.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1233.000000           1233.000000
# mean                  2.234388              4.367397
# std                   3.234762              3.594116
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# # CODING TASK #7. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
def incr_net_worth(net_worth):
    return net_worth * 1.10 

hr_df['DailyRate'] = hr_df['DailyRate'].apply(incr_net_worth)

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely     1212.2
# 1   49            NaN        No  Travel_Frequently      306.9
# 2   37         2090.0       Yes      Travel_Rarely     1510.3
# 3   33         2909.0        No  Travel_Frequently     1531.2
# 4   27         3468.0        No      Travel_Rarely      650.1
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
def double_daily(daily_rate):
    return (daily_rate * 2) + 100

hr_df['DailyRate'] = hr_df['DailyRate'].apply(double_daily)

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely     2524.4
# 1   49            NaN        No  Travel_Frequently      713.8
# 2   37         2090.0       Yes      Travel_Rarely     3120.6
# 3   33         2909.0        No  Travel_Frequently     3162.4
# 4   27         3468.0        No      Travel_Rarely     1400.2
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %%
total = hr_df['DailyRate'].sum()
total
# Out:
# 2742238.8000000003

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
plt.figure(figsize=(12, 8))
plt.hist(hr_df['MonthlyIncome'], bins=20,color='blue', edgecolor='red')
plt.title('Monthly Income Histogram')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.hist(hr_df['TotalWorkingYears'], bins=20,color='green', edgecolor='red')
plt.title('Total working years Histogram')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely     2524.4
# 1   49            NaN        No  Travel_Frequently      713.8
# 2   37         2090.0       Yes      Travel_Rarely     3120.6
# 3   33         2909.0        No  Travel_Frequently     3162.4
# 4   27         3468.0        No      Travel_Rarely     1400.2
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
# 3              1  ...                         3             80
# 4              1  ...                         4             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# 1                1                 10                      3                3
# 2                0                  7                      3                3
# 3                0                  8                      3                3
# 4                1                  6                      3                3
#
#   YearsAtCompany  YearsInCurrentRole YearsSinceLastPromotion  \
# 0              6                   4                       0
# 1             10                   7                       1
# 2              0                   0                       0
# 3              8                   7                       3
# 4              2                   2                       2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
hr_top = hr_df.head()

# %%
numeric_columns = hr_top.select_dtypes(include=[int, float]).columns


numeric_df = hr_top[numeric_columns]


corr_matrix = numeric_df.corr()


plt.figure(figsize=(12, 8))
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(corr_matrix, annot=True, cmap=cmap)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %%
kypho = pd.read_csv("kyphosis.csv")
kypho
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
kypho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
kypho.describe()
# Out:
#               Age     Number      Start
# count   81.000000  81.000000  81.000000
# mean    83.654321   4.049383  11.493827
# std     58.104251   1.619423   4.883962
# min      1.000000   2.000000   1.000000
# 25%     26.000000   3.000000   9.000000
# 50%     87.000000   4.000000  13.000000
# 75%    130.000000   5.000000  16.000000
# max    206.000000  10.000000  18.000000

# %%
kypho["Age"].mean()
# Out:
# 83.65432098765432

# %%
kypho["Age"].max()
# Out:
# 206

# %%
kypho["Age"].min()
# Out:
# 1

# %%
numeric_columns = kypho.select_dtypes(include=[int, float]).columns
kypho = kypho[numeric_columns]

# %%
corr_matrix = kypho.corr()
plt.figure(figsize=(12, 8))

cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(corr_matrix, annot=True, cmap="PiYG")
plt.title('Corr Heatmap')
plt.show()

# %%
kypho['Age'] = kypho['Age'].astype('float64')

# %%
kypho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     81 non-null     float64
#  1   Number  81 non-null     int64
#  2   Start   81 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 2.0 KB

# %%
def months_to_years(age_in_months):
    return age_in_months / 12

kypho['Age'] = kypho['Age'].apply(months_to_years)

# %%
kypho.head()
# Out:
#          Age  Number  Start
# 0   5.916667       3      5
# 1  13.166667       3     14
# 2  10.666667       4      5
# 3   0.166667       5      1
# 4   0.083333       4     15

# %%
kypho["Age in years"] = kypho["Age"]

# %%
kypho
# Out:
#           Age  Number  Start  Age in years
# 0    5.916667       3      5      5.916667
# 1   13.166667       3     14     13.166667
# 2   10.666667       4      5     10.666667
# 3    0.166667       5      1      0.166667
# 4    0.083333       4     15      0.083333
# ..        ...     ...    ...           ...
# 76  13.083333       3     13     13.083333
# 77   2.166667       7     13      2.166667
# 78  10.000000       2     13     10.000000
# 79   3.500000       7      6      3.500000
# 80   3.000000       4     13      3.000000
#
# [81 rows x 4 columns]

# %%
kypho["Age"].min()
# Out:
# 0.08333333333333333

# %%
kypho["Age"].max()
# Out:
# 17.166666666666668

# %% [markdown]
# # Great Job!

# %% [markdown]
# # <p style="background-color:green;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>Faydalı Olması Temennisiyle Teşekkürler</b></p>
# ![](https://www.techproeducation.com/logo/headerlogo.svg)
#
# <b>Yeniliklerden ilk siz haberdar olmak istiyorsanız lütfen bizi takip etmeyi unutmayın </b>[YouTube](https://www.youtube.com/c/techproeducation) | [Instagram](https://www.instagram.com/techproeducation) | [Facebook](https://www.facebook.com/techproeducation) | [Telegram](https://t.me/joinchat/HH2qRvA-ulh4OWbb) | [Watsapp](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0) | [Linkedin](https://www.linkedin.com/company/techproeducation/mycompany/) |
